# %% [markdown]
# # Microscopy figures
# This [Jupyter](http://jupyter.com) notebook was used to help us generate the microscopy figures for the [publication on the acinar complexity](https://www.authorea.com/274247/47HwqAxume3L2xkLOsg_SQ).

# %%
# Load the data and set up notebook
import matplotlib.pyplot as plt
# %matplotlib inline
import platform
import glob
import os
import pandas
import imageio
from matplotlib_scalebar.scalebar import ScaleBar

# %%
# Display and output defaults
plt.rc('image', cmap='gray', interpolation='nearest')  # Display all images in b&w and with 'nearest' interpolation
plt.rcParams['savefig.dpi'] = 300  # Save (PNG) images with a higher DPI, since Authorea cannot import PDFs...
plt.rcParams["savefig.transparent"] = True

# %% [markdown]
# Let's load the relevant data.
# First we load the 'Count' data from Eveline.
# This is what she assessed with the STEPanizer in tedious work.

# %%
# Different locations if running either on Linux or Windows
# ----
# We copied all the data 'nas_schittny' and 'anatera4' to the internal 'fast SSD' with
# ---
# rsync -av -m --include='**/' --include='**/*5slices/**' --exclude='*' '/run/user/1000/gvfs/smb-share:server=anatera4,share=share/SLS/' '/media/habi/Fast_SSD/Acini/'
# (obviously only works on Linux)
# ---
# so we can set
FastSSD = True
# to speed things up significantly
if 'debian' in platform.dist():
    if FastSSD:
        RootPath = os.path.join(os.sep, 'media', 'habi', 'Fast_SSD', 'Acini')
    else:
        RootPath = os.path.join(os.sep, 'home', 'habi', 'nas_gruppe_schittny', 'doc', 'David')
else:
    if FastSSD:
        RootPath = os.path.join('F:/', 'Acini')
    else:
        RootPath = os.path.join('\\\\nas.ana.unibe.ch\\', 'gruppe_schittny', 'Data', 'doc', 'David')
print('We are loading all the data from %s' % RootPath)
# Out:
# We are loading all the data from F:/Acini

# %%
# Different locations if running either on Linux or Windows
if 'debian' in platform.dist():
    location_volumes = '/run/user/1000/gvfs/smb-share:server=anatera4,share='
else:
    location_volumes = '\\\\anatera4\\'
# Load the data from this folder
terastation = location_volumes + os.path.join('share', 'SLS')
print('We are loading all the data from %s' % terastation)
# Out:
# We are loading all the data from \\anatera4\share\SLS

# %%
# Get a list of *all* excel files that Eveline exported from the STEPanizer
# Fortunately, she did NOT count in 2018
# Based on https://stackoverflow.com/a/14798263
StepanizerFiles_Eveline = sorted(glob.glob(os.path.join(RootPath, '**/*201[1234567]*.xls'), recursive=True))
if len(StepanizerFiles_Eveline):
    print('Eveline counted the alveoli in %s acini in total.' % len(StepanizerFiles_Eveline))
else:
    print('Mount the fast SSD please!!!')
# Out:
# Eveline counted the alveoli in 287 acini in total.

# %% [markdown]
# ----

# %% [markdown]
# Get a sampler of the tomography slices to compare them with microscopy slides.
# E.g., get *one* acinus per day, get the middle image of it and then image this *physical* slice on the microscope.
# (We got the slices from Stefan...)
# This if for the 'Comparison Images' at the end of the results.

# %%
Microscopy = pandas.DataFrame({'File': StepanizerFiles_Eveline})
Microscopy['Location'] = [os.path.dirname(f) for f in Microscopy.File]
Microscopy['NumImages'] = [len(glob.glob(os.path.join(f, '*.jpg'))) for f in Microscopy.Location]
Microscopy['MiddleImage'] = Microscopy.NumImages // 4  # we have _a and _b series, so half of it is the image set, and again half of it is the middle image
Microscopy['SelectedImage'] = [glob.glob(os.path.join(f, '*' + str(mi) + '_a.jpg'))[0] for f, mi in zip(Microscopy.Location, Microscopy.MiddleImage)]
Microscopy['Sample'] = [os.path.basename(f).split('-acinus')[0][1:] for f in Microscopy.File]
Microscopy['Animal'] = [os.path.basename(f).split('_R108C')[1].split('mrg-')[0][:3] for f in Microscopy.File]
Microscopy['Day'] = [int(os.path.basename(f).split('_R108C')[1].split('mrg-')[0][:2]) for f in Microscopy.File]
Microscopy['Acinus'] = [int(os.path.basename(f).split('acinus')[1].split('_')[0]) for f in Microscopy.File]

# %%
Microscopy.head()
# Out:
#                                                 File  \
# 0  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus03\voxe...
# 1  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus04\voxe...
# 2  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus07\voxe...
# 3  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus09\voxe...
# 4  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus10\voxe...
#
#                                             Location  NumImages  MiddleImage  \
# 0  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus03\voxe...        186           46
# 1  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus04\voxe...        264           66
# 2  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus07\voxe...        240           60
# 3  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus09\voxe...        248           62
# 4  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus10\voxe...        220           55
#
#                                        SelectedImage         Sample Animal  \
# 0  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus03\voxe...  R108C60Dt-mrg    60D
# 1  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus04\voxe...  R108C60Dt-mrg    60D
# 2  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus07\voxe...  R108C60Dt-mrg    60D
# 3  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus09\voxe...  R108C60Dt-mrg    60D
# 4  F:/Acini\2009f\mrg\R108C60Dt-mrg\acinus10\voxe...  R108C60Dt-mrg    60D
#
#    Day  Acinus
# 0   60       3
# 1   60       4
# 2   60       7
# 3   60       9
# 4   60      10

# %%
# Select one random sample per day (e.g. one random acinus)
# Based on https://stackoverflow.com/a/41566012/323100
Subset = Microscopy.groupby('Day').apply(lambda x: x.sample())

# %%
print('Image slices from these samples')
for c, i in Subset.iterrows():
    print('\t- From sample', i.Sample, 'we show Acinus\t', i.Acinus)
# Out:
# Image slices from these samples
# 	- From sample R108C04At-mrg we show Acinus	 50
# 	- From sample R108C10At-mrg we show Acinus	 20
# 	- From sample R108C21E_B1_mrg we show Acinus	 56
# 	- From sample R108C60Et-mrg we show Acinus	 8

# %%
for c, i in enumerate(Subset['SelectedImage']):
    plt.imshow(plt.imread(i))
    plt.title(os.path.dirname(Subset['Location'][c][len(RootPath):]) + '/.../...' + os.path.basename(Subset['SelectedImage'][c][-8:]))
    plt.show()

# %% [markdown]
# For *one* animal per day (selected randomly above) we imaged the middle slice of Stefans lung slices (usually slice nr. 8) on the microscope.
# The code below is used to get the middle disector-slice and the bottom TOMCAT reconstruction of exactly these samples and copy them to the 'Microscopy' subfolder for generating the relevant figures.

# %%
SamplesImaged = ['R108C04At-mrg',
                 'R108C10C_B1_mrg',
                 'R108C21E_B1_mrg',
                 'R108C60C_B1-mrg']

# %%
AciniImaged = [39, 32, 38, 4]

# %%
# We could do the selection of the relevant items from the dataframe a bit more clever
# But since we didn't think about it before, we just loop through the frame four times in a row :)
Indices = [None] * len(SamplesImaged)
for smpl in range(len(SamplesImaged)):
    for idx, row in Microscopy.iterrows():
        if row.Sample in SamplesImaged[smpl]:
            if row.Acinus == AciniImaged[smpl]:
                Indices[smpl] = idx
    print('Found acinus %s of sample %s at item %s of "Microscopy" dataframe' % (AciniImaged[smpl],
                                                                                 SamplesImaged[smpl],
                                                                                 Indices[smpl]))
# Out:
# Found acinus 39 of sample R108C04At-mrg at item 33 of "Microscopy" dataframe
# Found acinus 32 of sample R108C10C_B1_mrg at item 225 of "Microscopy" dataframe
# Found acinus 38 of sample R108C21E_B1_mrg at item 259 of "Microscopy" dataframe
# Found acinus 4 of sample R108C60C_B1-mrg at item 201 of "Microscopy" dataframe

# %%
for i in Indices:
    print(Microscopy.iloc[i])
    print(80 * '-')
# Out:
# File             F:/Acini\2010a\mrg\R108C04At-mrg\acinus39\voxe...
# Location         F:/Acini\2010a\mrg\R108C04At-mrg\acinus39\voxe...
# NumImages                                                       20
# MiddleImage                                                      5
# SelectedImage    F:/Acini\2010a\mrg\R108C04At-mrg\acinus39\voxe...
# Sample                                               R108C04At-mrg
# Animal                                                         04A
# Day                                                              4
# Acinus                                                          39
# Name: 33, dtype: object
# --------------------------------------------------------------------------------
# File             F:/Acini\2010c_tape\R108C10C_B1_mrg_10c\acinus...
# Location         F:/Acini\2010c_tape\R108C10C_B1_mrg_10c\acinus...
# NumImages                                                       70
# MiddleImage                                                     17
# SelectedImage    F:/Acini\2010c_tape\R108C10C_B1_mrg_10c\acinus...
# Sample                                             R108C10C_B1_mrg
# Animal                                                         10C
# Day                                                             10
# Acinus                                                          32
# Name: 225, dtype: object
# --------------------------------------------------------------------------------
# File             F:/Acini\2010c_tape\R108C21E_B1_mrg_10c\acinus...
# Location         F:/Acini\2010c_tape\R108C21E_B1_mrg_10c\acinus...
# NumImages                                                      112
# MiddleImage                                                     28
# SelectedImage    F:/Acini\2010c_tape\R108C21E_B1_mrg_10c\acinus...
# Sample                                             R108C21E_B1_mrg
# Animal                                                         21E
# Day                                                             21
# Acinus                                                          38
# Name: 259, dtype: object
# --------------------------------------------------------------------------------
# File             F:/Acini\2010a\mrg\R108C60C_B1-mrg\acinus04\vo...
# Location         F:/Acini\2010a\mrg\R108C60C_B1-mrg\acinus04\vo...
# NumImages                                                       86
# MiddleImage                                                     21
# SelectedImage    F:/Acini\2010a\mrg\R108C60C_B1-mrg\acinus04\vo...
# Sample                                             R108C60C_B1-mrg
# Animal                                                         60C
# Day                                                             60
# Acinus                                                           4
# Name: 201, dtype: object
# --------------------------------------------------------------------------------

# %%
for i in Indices:
    print(Microscopy.iloc[i].SelectedImage)
    print(80 * '-')
# Out:
# F:/Acini\2010a\mrg\R108C04At-mrg\acinus39\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C04At-mrg-acinus39_5_a.jpg
# --------------------------------------------------------------------------------
# F:/Acini\2010c_tape\R108C10C_B1_mrg_10c\acinus32\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C10C_B1_mrg-acinus32_17_a.jpg
# --------------------------------------------------------------------------------
# F:/Acini\2010c_tape\R108C21E_B1_mrg_10c\acinus38\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C21E_B1_mrg-acinus38_28_a.jpg
# --------------------------------------------------------------------------------
# F:/Acini\2010a\mrg\R108C60C_B1-mrg\acinus04\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C60C_B1-mrg-acinus04_21_a.jpg
# --------------------------------------------------------------------------------

# %%
# Copy acinus images to STEPanizer subfolder
from shutil import copyfile
for i in Indices:
    print('Copying %s to "STEPanizer" subfolder' % Microscopy.iloc[i].SelectedImage)
    copyfile(Microscopy.iloc[i].SelectedImage,
             os.path.join('Microscopy', 'STEPanizer', os.path.basename(Microscopy.iloc[i].SelectedImage)))
# Out:
# Copying F:/Acini\2010a\mrg\R108C04At-mrg\acinus39\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C04At-mrg-acinus39_5_a.jpg to "STEPanizer" subfolder
# Copying F:/Acini\2010c_tape\R108C10C_B1_mrg_10c\acinus32\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C10C_B1_mrg-acinus32_17_a.jpg to "STEPanizer" subfolder
# Copying F:/Acini\2010c_tape\R108C21E_B1_mrg_10c\acinus38\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C21E_B1_mrg-acinus38_28_a.jpg to "STEPanizer" subfolder
# Copying F:/Acini\2010a\mrg\R108C60C_B1-mrg\acinus04\voxelsize1.48-every10slice-DisectorThickness-7.40um-or5slices\R108C60C_B1-mrg-acinus04_21_a.jpg to "STEPanizer" subfolder

# %%
# Copy bottom reconstruction of top scan from selected sample to Microscopy subfolder
for i in Indices:
    # Do some string manipulation to get us the correct directory
    lookuppath = terastation + os.path.join(os.path.dirname(os.path.dirname(Microscopy.iloc[i].Location[len(RootPath):])),
                                            'rec_8bit')
    # Get all the files in there, sorted
    files = sorted(glob.glob(os.path.join(lookuppath, '*.tif')))
    # The last file is the bottom image of the top stack, copy this one, now
    print('Copying %s to "TOMCAT" subfolder' % files[-1])
    copyfile(files[-1],
             os.path.join('Microscopy', 'TOMCAT', os.path.basename(files[-1])))
# Out:
# Copying \\anatera4\share\SLS\2010a\mrg\R108C04At-mrg\rec_8bit\R108C04At-mrg1024.rec.8bit.tif to "TOMCAT" subfolder
# Copying \\anatera4\share\SLS\2010c_tape\R108C10C_B1_mrg_10c\rec_8bit\R108C10C_B1_mrg1024.rec.8bit.tif to "TOMCAT" subfolder
# Copying \\anatera4\share\SLS\2010c_tape\R108C21E_B1_mrg_10c\rec_8bit\R108C21E_B1_mrg1024.rec.8bit.tif to "TOMCAT" subfolder
# Copying \\anatera4\share\SLS\2010a\mrg\R108C60C_B1-mrg\rec_8bit\R108C60C_B1-mrg1024.rec.8bit.tif to "TOMCAT" subfolder

# %%
print('Done with copying the data around.')
print('Now, let us generate the figure.')
# Out:
# Done with copying the data around.
# Now, let us generate the figure.

# %%
# Setup scale bar
plt.rcParams['scalebar.location'] = 'lower left'
plt.rcParams['scalebar.frameon'] = False
plt.rcParams['scalebar.color'] = 'black'

# %%
# color-corrected the microscopy TIFFs with https://github.com/pmascalchi/ImageJ_Auto-white-balance-correction
# scalebar from microscopy sliced measured in ImageJ: 1.85 pixels/um --> 0.54 um/px

# %%
# Set pixel sizes, for scalebar
pixelsizemicroscopy = 0.54
pixelsizetomcat = 1.48

# %%
# Read the microscopy slides
mic04 = imageio.imread(glob.glob(os.path.join('Microscopy', 'Slides', '*background*', 'R108C04*.tif'))[0])
mic10 = imageio.imread(glob.glob(os.path.join('Microscopy', 'Slides', '*background*', 'R108C10*.tif'))[0])
mic21 = imageio.imread(glob.glob(os.path.join('Microscopy', 'Slides', '*background*', 'R108C21*.tif'))[0])
mic60 = imageio.imread(glob.glob(os.path.join('Microscopy', 'Slides', '*background*', 'R108C60*.tif'))[0])

# %%
# Read the TOMCAT reconstructions
tomcat04 = imageio.imread(glob.glob(os.path.join('Microscopy', 'TOMCAT', 'R108C04*.8bit.edit.*'))[0])
tomcat10 = imageio.imread(glob.glob(os.path.join('Microscopy', 'TOMCAT', 'R108C10*.8bit.edit.*'))[0])
tomcat21 = imageio.imread(glob.glob(os.path.join('Microscopy', 'TOMCAT', 'R108C21*.8bit.edit.*'))[0])
tomcat60 = imageio.imread(glob.glob(os.path.join('Microscopy', 'TOMCAT', 'R108C60*.8bit.edit.*'))[0])

# %%
# Read the STEPanizer files
stepanizer04 = imageio.imread(glob.glob(os.path.join('Microscopy', 'STEPanizer', 'R108C04*acinus*.edit.*'))[0])
stepanizer10 = imageio.imread(glob.glob(os.path.join('Microscopy', 'STEPanizer', 'R108C10*acinus*.edit.*'))[0])
stepanizer21 = imageio.imread(glob.glob(os.path.join('Microscopy', 'STEPanizer', 'R108C21*acinus*.edit.*'))[0])
stepanizer60 = imageio.imread(glob.glob(os.path.join('Microscopy', 'STEPanizer', 'R108C60*acinus*.edit.*'))[0])

# %%
# Set figure size to half-height A4
plt.rcParams['figure.figsize'] = (8.27, 11.69 / 2)  # Size up figure to A4

# %%
# Microscopy
plt.subplot(341)
plt.imshow(mic04)
plt.gca().add_artist(ScaleBar(pixelsizemicroscopy, 'um',
                              frameon=True, box_color='white', box_alpha=0.618))
# plt.gca().text(0,0,
#                'A', color='black', fontsize=12,
#                verticalalignment='top', horizontalalignment='left')
plt.axis('off')
plt.subplot(342)
plt.imshow(mic10)
plt.gca().add_artist(ScaleBar(pixelsizemicroscopy, 'um',
                              frameon=True, box_color='white', box_alpha=0.618))
plt.axis('off')
plt.subplot(343)
plt.imshow(mic21)
plt.gca().add_artist(ScaleBar(pixelsizemicroscopy, 'um',
                              frameon=True, box_color='white', box_alpha=0.618))
plt.axis('off')
plt.subplot(344)
plt.imshow(mic60)
plt.gca().add_artist(ScaleBar(pixelsizemicroscopy, 'um',
                              frameon=True, box_color='white', box_alpha=0.618))
plt.axis('off')
# TOMCAT
plt.subplot(345)
plt.imshow(tomcat04)
plt.gca().add_artist(ScaleBar(pixelsizetomcat, 'um', color='white'))
plt.axis('off')
plt.subplot(346)
plt.imshow(tomcat10)
plt.gca().add_artist(ScaleBar(pixelsizetomcat, 'um', color='white'))
# plt.gca().text(0,0,
#                'F', color='white', fontsize=12,
#                verticalalignment='top', horizontalalignment='left')
plt.axis('off')
plt.subplot(347)
plt.imshow(tomcat21)
plt.gca().add_artist(ScaleBar(pixelsizetomcat, 'um', color='white'))
plt.axis('off')
plt.subplot(348)
plt.imshow(tomcat60)
plt.gca().add_artist(ScaleBar(pixelsizetomcat, 'um', color='white'))
plt.axis('off')
# STEPanizer
plt.subplot(349)
plt.imshow(stepanizer04)
plt.axis('off')
plt.subplot(3,4,10)
plt.imshow(stepanizer10)
plt.axis('off')
plt.subplot(3,4,11)
plt.imshow(stepanizer21)
plt.axis('off')
plt.subplot(3,4,12)
plt.imshow(stepanizer60)
# plt.gca().text(0,0,
#                'L', color='white', fontsize=12,
#                verticalalignment='top', horizontalalignment='left')
plt.axis('off')
# Setup for figure
# plt.tight_layout()
plt.subplots_adjust(0,0,1,0.6,0,0)
plt.savefig(os.path.join('Microscopy',
                         'Fig01.png'),
            bbox_inches='tight')
plt.show()

# %%
# left  = 0.125  # the left side of the subplots of the figure
# right = 0.9    # the right side of the subplots of the figure
# bottom = 0.1   # the bottom of the subplots of the figure
# top = 0.9      # the top of the subplots of the figure
# wspace = 0.2   # the amount of width reserved for space between subplots,
#                # expressed as a fraction of the average axis width
# hspace = 0.2   # the amount of height reserved for space between subplots,
#                # expressed as a fraction of the average axis height
